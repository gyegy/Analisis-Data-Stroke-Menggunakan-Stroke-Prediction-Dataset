# %% [markdown]
# **Pertemuan 1**

# %% [markdown]
# # **Analisis Data Stroke Menggunakan Stroke Prediction Dataset**

# %%
import pandas as pd

# %%
path = "/content/drive/MyDrive/Dataset Praktikum AVD/healthcare-dataset-stroke-data.csv"

df = pd.read_csv(path)

df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# ## **Business Understanding**

# %% [markdown]
# ### **Business Objective**

# %% [markdown]
# Tujuan dari analisis ini adalah untuk melihat faktor-faktor yang berhubungan dengan penyakit stroke berdasarkan data kesehatan pasien.
# Dari analisis ini diharapkan bisa diketahui karakteristik pasien yang memiliki risiko stroke lebih tinggi.

# %% [markdown]
# ### **Assess Situation**

# %% [markdown]
# Stroke merupakan penyakit yang dipengaruhi oleh beberapa faktor seperti umur, hipertensi, penyakit jantung, kadar glukosa, dan BMI.
# Pada dataset ini terdapat data pasien yang terkena stroke dan yang tidak, sehingga bisa dibandingkan untuk melihat perbedaannya.Terdapat sedikit data yang kosong pada kolom BMI dan jumlah data stroke lebih sedikit dibandingkan yang tidak stroke.

# %% [markdown]
# ### **Analytic Goals Project Plan**

# %% [markdown]
# Analisis akan dilakukan dengan melihat gambaran umum data, mengecek data yang kosong, lalu membandingkan kondisi pasien stroke dan tidak stroke berdasarkan umur, BMI, dan kadar glukosa.
# Hasil dari analisis ini akan digunakan untuk mengetahui faktor yang paling berpengaruh terhadap stroke dan sebagai persiapan untuk tahap modeling.
