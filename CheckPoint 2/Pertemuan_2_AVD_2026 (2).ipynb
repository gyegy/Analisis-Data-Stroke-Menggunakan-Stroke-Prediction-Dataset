# %% [markdown]
# # **ANALISIS GLOBAL SUPER STORE 2016**

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# ## **Business Objective**

# %% [markdown]
# [Analisis Performa Bisnis Global Super Store]
#
# Analisis pada data transaksi Global Super Store bertujuan untuk membantu pihak manajemen dalam memahami, mengevaluasi, serta mengoptimalkan kinerja operasional dan finansial perusahaan di tingkat global. Fokus utama analisis ini mencakup pemantauan tren penjualan dan profitabilitas berdasarkan dimensi waktu, segmentasi pelanggan (Consumer, Corporate, Home Office), sebaran wilayah pasar (Market & Country), serta kategori produk.
#
# Sebagai perusahaan retail skala internasional yang beroperasi di berbagai wilayah seperti USCA, Asia Pacific, Europe, Africa, dan LATAM, diperlukan pendekatan analitik data yang mendalam. Hal ini bertujuan untuk menghasilkan wawasan (insight) mengenai produk mana yang memberikan margin keuntungan tertinggi, wilayah mana yang memiliki potensi pertumbuhan besar, serta mengidentifikasi faktor-faktor yang menyebabkan kerugian pada transaksi tertentu (seperti yang tercermin pada kolom 'Keterangan').

# %% [markdown]
# ## **Assess Situation**

# %% [markdown]
# Situasi bisnis yang mendasari analisis ini adalah skala operasional Global Super Store yang sangat luas, mencakup berbagai wilayah geografis (Market) dan negara di seluruh dunia. Dengan volume transaksi yang besar serta keragaman kategori produk dan segmen pelanggan, perusahaan menghadapi tantangan dalam memantau profitabilitas secara konsisten di setiap pasar. Manajemen membutuhkan pemahaman yang lebih tajam mengenai faktor-faktor yang mendorong keuntungan atau justru memicu kerugian di tiap wilayah untuk memastikan keberlanjutan bisnis di tingkat internasional.
#
# Meskipun seluruh data transaksi telah tercatat secara digital, terdapat tantangan dalam menyelaraskan performa antar wilayah yang memiliki karakteristik pasar berbeda. Munculnya indikator transaksi "Rugi" pada beberapa baris data menunjukkan adanya ketidakkonsistenan dalam efisiensi operasional atau strategi penetapan harga di pasar tertentu. Kondisi ini menyulitkan pihak manajemen dalam melakukan evaluasi performa global secara objektif tanpa adanya visualisasi dan analisis yang mendalam. Oleh karena itu, diperlukan proses analisis data yang sistematis untuk menilai kondisi data yang ada, mengidentifikasi pola kerugian, serta menggali insight yang relevan guna mendukung pengambilan keputusan bisnis yang lebih akurat dalam mengoptimalkan profit global.

# %% [markdown]
# ## **Analytic Goals Project Plan**

# %% [markdown]
# Rencana proyek ini mencakup langkah-langkah terstruktur dari pengolahan data hingga penyajian hasil untuk mencapai tujuan bisnis yang telah ditetapkan:
#
# * Pengumpulan dan Eksplorasi Data (Data Understanding):
# * Pembersihan Data (Data Preparation):
# * Analisis Data (Data Analysis):
# * Analisis Geografis: Memetakan performa penjualan dan profit di berbagai wilayah pasar dunia (Market).
# * Visualisasi Data dan Reporting:
# * Menyimpulkan temuan utama dari hasil analisis.
#
# Tujuan utama dari analisis data ini adalah untuk menghasilkan wawasan yang dapat ditindaklanjuti guna meningkatkan performa bisnis Global Super Store secara menyeluruh. Secara spesifik, tujuan yang ingin dicapai adalah:
#
# * Mengidentifikasi Tren dan Pola Penjualan
# * Menganalisis Profitabilitas Global
# * Evaluasi Kontribusi Wilayah dan Kategori
# * Memahami Segmentasi Pelanggan
# * Menghasilkan visualisasi data yang komunikatif dan akurat sebagai alat bantu manajemen
# * Menyediakan Dasar Pengambilan Keputusann

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Memuat Dataset**

# %% [markdown]
# Sumber dataset ini berasal dari Globar SuperStore di Tahun 2016, yang bertujuan untuk mengevaluasi & meningkatkan penjualan dalam skala Global

# %%
file = '/content/V1_GlobalSuperStore2016.csv'

df = pd.read_csv(file)
df
# Out:
#      Unnamed: 0                  Order ID        Order Date     Customer Name  \
# 0             0  CA-2014-AB10015140-41954        11-11-2014     Aaron Bergman
# 1             1    IN-2014-JR162107-41675        2014-02-05     Justin Ritter
# 2             2    IN-2014-CR127307-41929  October 17, 2014      Craig Reiter
# 3             3   ES-2014-KM1637548-41667        28-01-2014  Katherine Murray
# 4             4   SG-2014-RH9495111-41948  05 November 2014       Rick Hansen
# ..          ...                       ...               ...               ...
# 150         150   IT-2012-ZC2191048-41174        2012/09/22  Zuschuss Carroll
# 151         151   IN-2013-MB1808592-41378        14-04-2013        Mick Brown
# 152         152  CA-2012-AB10015140-40974        2012-03-06     Aaron Bergman
# 153         153    IN-2013-NC186257-41401        2013/05/07       Noah Childs
# 154         154    IN-2015-JH158207-42140       16 May 2015       John Huston
#
# ...

# %% [markdown]
# ## **Deskripsi Data**

# %% [markdown]
# ### **Informasi Dasar**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     155 non-null    int64
#  1   Order ID       155 non-null    object
#  2   Order Date     155 non-null    object
#  3   Customer Name  155 non-null    object
#  4   Segment        155 non-null    object
#  5   Country        155 non-null    object
#  6   Market         155 non-null    object
#  7   Product ID     31 non-null     object
#  8   Category       155 non-null    object
#  9   Product Name   155 non-null    object
#  10  Sales          155 non-null    float64
#  11  Quantity       155 non-null    int64
#  12  Profit         117 non-null    float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 15.9+ KB

# %% [markdown]
# Berdasarkan data di atas, dapat diketahui bahwa dataset ini memiliki 155 Baris dan 13 Kolom

# %% [markdown]
# ### **Informasi Lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     155 non-null    int64
#  1   Order ID       155 non-null    object
#  2   Order Date     155 non-null    object
#  3   Customer Name  155 non-null    object
#  4   Segment        155 non-null    object
#  5   Country        155 non-null    object
#  6   Market         155 non-null    object
#  7   Product ID     31 non-null     object
#  8   Category       155 non-null    object
#  9   Product Name   155 non-null    object
#  10  Sales          155 non-null    float64
#  11  Quantity       155 non-null    int64
#  12  Profit         117 non-null    float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 15.9+ KB

# %% [markdown]
# 1. Unnamed: 0
#         Jumlah baris: 155
#         Tipe data: int64
#         Deskripsi: Kolom Tanpa Nama
#
# 2. Order ID:
#         Jumlah baris: 155
#         Tipe data: object
#         Deskripsi: ID Pesanan
#
# 3. Order Date:
#         Jumlah baris: 155
#         Tipe data: object
#         Deskripsi: Tanggal Pesanan
#
# 4. Customer Name:
#         Jumlah baris: 155
#         Tipe data: object
#         Deskripsi: Nama Pembeli
#
# 5. Segment:
#         Jumlah baris: 155
#         Tipe data: object
#         Deskripsi: Segment Pembeli
#
# 6. Country:
#         Jumlah baris: 155
#         Tipe data: object
#         Deskripsi: Kota
#
# 7. Market:
#         Jumlah baris: 155
#         Tipe data: object
#         Deskripsi: Market Pembeli
#
# 8. Product ID:
#         Jumlah baris: 31
#         Tipe data: Object
#         Deskripsi: ID Produk
#
# 9. Category:
#         Jumlah baris: 155
#         Tipe data: Object
#         Deskripsi: Kategori Produk
#
# 10. Product Name:
#         Jumlah baris: 155
#         Tipe data: Object
#         Deskripsi: Nama Produk
#
# 11. Sales:
#         Jumlah baris: 155
#         Tipe data: float64
#         Deskripsi: Penjualan
#
# 12. Quantity:
#         Jumlah baris: 155
#         Tipe data: int64
#         Deskripsi: Jumlah
#
# 13. Profit:
#         Jumlah baris: 117
#         Tipe data: float64
#         Deskripsi: Keuntungan

# %% [markdown]
# ### **Informasi Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0                  Order ID  Order Date  Customer Name  \
# count   155.000000                       155         155            155
# unique         NaN                       132         139            102
# top            NaN  CA-2012-AB10015140-40974  28-01-2014  Aaron Hawkins
# freq           NaN                         4           2             12
# mean     77.000000                       NaN         NaN            NaN
# std      44.888751                       NaN         NaN            NaN
# min       0.000000                       NaN         NaN            NaN
# 25%      38.500000                       NaN         NaN            NaN
# 50%      77.000000                       NaN         NaN            NaN
# 75%     115.500000                       NaN         NaN            NaN
# max     154.000000                       NaN         NaN            NaN
#
#          Segment        Country        Market   Product ID    Category  \
# ...

# %% [markdown]
# 1. Count (Kelengkapan Data)
# Berdasarkan data, total baris transaksi adalah 155. Maka dapat disimpulkan:
# * Profit hilang 38 data (155 - 117)
# * Product ID hilang 124 data (155 - 31)
#
# Kesimpulan: Kolom Profit dan Product ID mengandung missing values, sementara kolom lainnya udah lengkap (155 data)
#
#
#
# ---
#
#
#
# 2. Mean vs Median (Distribusi Data)
#
# * Kolom Sales
#   * Mean = 2.269,12
#   * Median = 2.221,80 - Nilai rata-rata sedikit lebih besar dari median
#
#   menunjukkan adanya beberapa transaksi dengan nilai penjualan yang sangat tinggi (outlier), namun distribusinya masih relatif mendekati simetris.
#
# * Kolom Quantity
#  * Mean = 10,02
#  * Median = 6,00 - Rata-rata pembelian jauh lebih besar dari median
#
#  Ini menandakan adanya transaksi dalam jumlah besar (grosir/bulk) yang menarik nilai rata-rata ke atas.
#
# * Kolom Profit
#   * Mean = 417,48
#   * Median = 276,84 - Perbedaan yang signifikan antara mean dan median menunjukkan bahwa profitabilitas sangat dipengaruhi oleh transaksi-transaksi dengan keuntungan sangat besar, sementara mayoritas transaksi berada di nilai yang lebih rendah.
#
# Kesimpulan: Secara keseluruhan, data bersifat right-skewed (condong ke kanan), di mana terdapat nilai-nilai ekstrem tinggi yang memengaruhi nilai rata-rata di semua variabel utama.
#
#
#
# ---
#
#
#
# 3. Min dan Max (Validasi Logika)
#
# * Sales
#   * Min = 8,00
#   * Max = 7.958,58
#
# * Quantity
#   * Min = 1
#   * Max = 114
#
# * Profit
#   * Min = -2.211,16
#   * Max = 3.979,08
#
# Kesimpulan:
# * Nilai Quantity maksimal sebesar 114 unit dalam satu transaksi perlu divalidasi apakah ini merupakan pesanan korporat atau kesalahan input.
#
# * Nilai Profit minimum yang negatif (-2.211) menunjukkan adanya kerugian besar pada transaksi tertentu.
#
# * Rentang nilai Sales yang lebar (8 hingga hampir 8.000) adalah wajar untuk bisnis retail global yang menjual berbagai kategori produk.
#
#
#
# ---
#
#
#
# 4. Standar Deviasi (std) - Variabilitas Data
#
# * Sales
#   * Mean = 2.269,12
#   * Std = 1.557,60
#
# * Profit
#   * Mean = 417,48
#   * Std = 676,75
#
# Kesimpulan:
#
# * Pada kolom Sales, nilai standar deviasi yang cukup tinggi (sekitar 68% dari mean) menunjukkan variasi harga produk yang dijual sangat beragam.
#
# * Pada kolom Profit, nilai standar deviasi yang jauh lebih besar (676,75) daripada rata-ratanya (417,48) mengindikasikan bahwa tingkat keuntungan antar transaksi sangat tidak stabil/bervariasi, mulai dari kerugian besar hingga keuntungan yang sangat tinggi.

# %% [markdown]
# ## **VERIFIKASI KUALITAS DATA**

# %% [markdown]
# ### **Data Type Check**

# %% [markdown]
# Kita akan mengecek tipe data dari setiap kolom apakah sudah sesuai atau tidak. Agar insight serta visualisasi yang akan kita buat menjadi akurat.
#
# Dan dapat dilihat dibawah ini, kolom Order Date dengan tipe data object, seharusnya kolom ini bertipe data kan date bukan object. Selain itu, semua kolom sudah sesuai.

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# Order ID          object
# Order Date        object
# Customer Name     object
# Segment           object
# Country           object
# Market            object
# Product ID        object
# Category          object
# Product Name      object
# Sales            float64
# Quantity           int64
# Profit           float64
# dtype: object

# %% [markdown]
# ### **Incosistent Values**

# %% [markdown]
# Pada tahap ini, kita perlu mengecek kekonsistenan data, contoh nya dalam penulisan. Hal ini dilakukan agar data tidak terduplikat dengan baris yang sebenarnya sama akan tetapi bisa terduplikat karena tidak konsisten.

# %% [markdown]
# 1. **Order Date**
#
# Pada kolom ini, dapat terlihat format tanggal tidak konsisten dengan format yang sama. Semua memiliki format yang berbeda-beda. Maka hal ini perlu ditangani dengan cara kita akan menyamakan format nya menjadi yyy-mm-dd.

# %%
print(df['Order Date'].unique())
# Out:
# ['11-11-2014' '2014-02-05' 'October 17, 2014' '28-01-2014'
#  '05 November 2014' '28 June 2014' '06 November 2012' '14-04-2013'
#  '11 November 2014' '2012/03/06' 'March 06, 2012' '19-04-2013'
#  'December 26, 2012' 'November 13, 2013' '2014-06-06' '31-07-2015'
#  'February 19, 2012' '08-09-2015' '2015/01/31' '05 December 2015'
#  '2013-08-08' '2012-03-06' '01 May 2012' '27-02-2014' 'July 31, 2015'
#  '05-09-2015' '16 December 2012' '2012/03/13' '21 April 2012'
#  'February 24, 2013' '27-12-2012' '17 July 2013' 'December 27, 2013'
#  'November 02, 2012' '13 September 2012' '12 May 2012' '2012-12-30'
#  '14-01-2015' '10 January 2012' '2014/08/22' '2015-11-11'
#  '26 September 2015' '13 December 2013' '2012/09/22' '2014/03/21'
#  '2014-03-08' '28 August 2015' '2015-05-01' '18-12-2015' '2012-10-24'
#  '18 September 2015' '2012/12/16' '2014-12-18' '30 May 2013' '21-04-2012'
#  '2013-05-25' '2015-08-05' '2012-05-12' '2015/03/11' '2015-12-19'
# ...

# %% [markdown]
# 2. **Category**
#
# Dapat dilihat, terdapat banyak sekali ketidakkonsistenan data pada pada kolom Category.
#
# Contohnya, kalimat technology, Technology, tECHNOLOGY, sebenarnya memiliki makna yang sama, akan tetapi karena data tidak konsisten hal ini justru dapat menyesatkan inight & visualisasi.

# %%
print(df['Category'].unique())
# Out:
# ['Technology' 'Furniture' 'tECHNOLOGY' 'TECHNOLOGY' 'furniture'
#  'Office Supplies' 'FURNITURE' 'office supplies' 'OFFICE SUPPLIES'
#  'oFFICE sUPPLIES' 'Office supplies' 'fURNITURE' 'technology']

# %% [markdown]
# ### **Missing Values**

# %% [markdown]
# Pada tahap ini, kita akan melihat seberapa banyak data yang hilang pada seluruh kolom. Dan terlihat bahwa kolom:
# * Product Id
#
# Memiliki missing values sekitar 80%, yang dimana ini cukup besar indikasi hilang nya data pada kolom tersebut. Sehingga perlu ditangani atau dihapus.
#
# * Profit
#
# Memiliki missing values sekitar 24% yang dimana hal ini perlu ditangani dengan cara mau ditangani atau dihapus.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                Null Ratio in %
# Unnamed: 0            0.000000
# Order ID              0.000000
# Order Date            0.000000
# Customer Name         0.000000
# Segment               0.000000
# Country               0.000000
# Market                0.000000
# Product ID           80.000000
# Category              0.000000
# Product Name          0.000000
# Sales                 0.000000
# Quantity              0.000000
# Profit               24.516129

# %% [markdown]
# ### **Duplicated Values**

# %% [markdown]
# Pada tahap ini, kita akan mengecek duplikasi pada dataset. Hal ini dilakukan agar dataset memiliki insight dan hasil yang bersih.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Order ID, Order Date, Customer Name, Segment, Country, Market, Product ID, Category, Product Name, Sales, Quantity, Profit]
# Index: []

# %% [markdown]
# Terlihat pada dataset ini tidak ada duplikasi. Maka hal ini tidak perlu ditangani, namun jika ingin menangani anda dapat mengetikkan
#
# df = df.drop_duplicates()

# %% [markdown]
# ### **Outliers Values**

# %% [markdown]
# Pada tahap ini, kita akan melihat nilai ekstrem (outliers) pada kolom yang bertipe data kan numerik. Hal ini dilakukan agar mendapatkan insight yang akurat sehingga dapat memperkuat analisis dan model yang akan kita bangun nantinya.
#
# Akan tetapi memang tidak semua kolom perlu kita tangani, kita harus tetap melihat dan memahami tujuan dari setiap kolom yang ada di dataset.
#
# Dan terlihat kolom
# * Quantity
#
# Dengan presentase 5%
# * Profit
#
# Dengan presentase 3%
#
# * Sales
#
# Dengan presentase 0.6% (dibawah 1%)

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom       Persentase Outliers
# Unnamed: 0             0.000000
# Sales                  0.645161
# Quantity               5.806452
# Profit                 3.870968

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Quantity'])
plt.title('Boxplot of Quantity')
plt.ylabel('Quantity')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Profit'])
plt.title('Boxplot of Profit')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# # **Eksplorasi Data (EDA)**

# %% [markdown]
# ## **Comparison/Perbandingan**

# %% [markdown]
# Aktivitas: Membandingkan total nominal penjualan (Sales) di setiap wilayah pasar (Market).
#
# Tujuan: Mengidentifikasi wilayah mana yang memberikan kontribusi pendapatan terbesar dan membandingkan performa antar wilayah secara langsung.
#
# Visualisasi: Bar Chart (Grafik Batang).

# %%
penjualan_market = df.groupby('Market')['Sales'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=penjualan_market.index, y=penjualan_market.values, palette='viridis', hue=penjualan_market.index, legend=False)
plt.title('Total Penjualan Berdasarkan Market')
plt.xlabel('Market')
plt.ylabel('Total Penjualan')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## **Composition/Komposisi**

# %% [markdown]
# Aktivitas: Melihat proporsi atau persentase total penjualan berdasarkan kategori produk (Category).
#
# Tujuan: Mengetahui kategori produk mana yang paling mendominasi portofolio penjualan perusahaan secara keseluruhan.
#
# Visualisasi: Pie Chart (Grafik Lingkaran).

# %%
sales_by_category = df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
sales_by_category_top3 = sales_by_category.head(3)

plt.figure(figsize=(10, 8))
sales_by_category_top3.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proporsi 3 Kategori Produk Teratas Berdasarkan Total Penjualan')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## **Distribution/Distribusi**

# %% [markdown]
# Aktivitas: Menganalisis penyebaran nilai transaksi pada kolom Sales.
#
# Tujuan: Melihat apakah mayoritas transaksi bernilai kecil atau besar, serta mendeteksi adanya kecondongan (skewness) dalam data penjualan.
#
# Visualisasi: Histogram.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Sales'], bins=20, kde=True)
plt.title('Distribusi Penjualan (Sales)')
plt.xlabel('Sales')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ## **Relationship/Hubungan**

# %% [markdown]
# Aktivitas: Menganalisis korelasi antara nilai penjualan (Sales) dengan keuntungan (Profit).
#
# Tujuan: Mengetahui apakah peningkatan penjualan selalu berbanding lurus dengan peningkatan profit, serta mengidentifikasi transaksi yang memiliki penjualan tinggi namun justru menghasilkan kerugian.
#
# Visualisasi: Heatmap

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['Sales', 'Profit']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi antara Sales dan Profit')
plt.show()

# %% [markdown]
# # **Menyimpan Dataset**

# %%
df.to_csv('[Bersih]GlobalSuperStore2016.csv', index=False)
